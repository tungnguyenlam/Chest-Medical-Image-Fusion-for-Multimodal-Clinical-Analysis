# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

cwd = os.getcwd()
if not cwd.endswith('process-data'):
    raise Exception('Please run this script from the process-data directory')

root_dir = os.path.abspath(os.path.join(cwd, '..', '..'))
data_dir = os.path.join(root_dir, 'data')

print(root_dir)
# Out:
# /home/tungnguyen/Programming/Chest-Medical-Image-Fusion-for-Multimodal-Clinical-Analysis

# %% [markdown]
# ## CXR-LT 2023

# %%
cxr_lt_2023_pt = os.path.join(root_dir, 'data/CXR-LT/cxr-lt-multi-label-long-tailed-classification-on-chest-x-rays-2.0.0/cxr-lt-2023')

dev_sample_sub_df = pd.read_csv(os.path.join(cxr_lt_2023_pt, 'development_sample_submission.csv'))

# %%
print("---"*10)
dev_sample_sub_df.head(5)
# Out:
# ------------------------------
#                                        dicom_id  Atelectasis  \
# 0  2833b85f-3bb4273f-cffd3794-2bf2cd57-7ddb3f5f     0.033536
# 1  7fdad032-90608fe2-c1f5a700-bf95f6f9-e9b0dbc7     0.017256
# 2  8b88f03a-2004113d-4118def5-35820db5-d0913df8     0.031781
# 3  e4ee2428-245e9222-399ef211-62b44204-35580e8d     0.038624
# 4  2630b0b8-2d5af3a6-1a02c2ca-952e9535-b44c35ee     0.039083
#
#    Calcification of the Aorta  Cardiomegaly  Consolidation     Edema  \
# 0                    0.000823      0.069515       0.037374  0.018542
# 1                    0.001685      0.057716       0.034736  0.011108
# 2                    0.005160      0.091920       0.012458  0.013892
# 3                    0.010154      0.220779       0.012634  0.033728
# 4                    0.003445      0.141827       0.054820  0.029596
#
#    Emphysema  Enlarged Cardiomediastinum  Fibrosis  Fracture  ...  \
# 0   0.001762                    0.115628  0.000941  0.029183  ...
# ...

# %%
print("---"*10)
dev_sample_sub_df.info()
# Out:
# ------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 36769 entries, 0 to 36768
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   dicom_id                    36769 non-null  str
#  1   Atelectasis                 36769 non-null  float64
#  2   Calcification of the Aorta  36769 non-null  float64
#  3   Cardiomegaly                36769 non-null  float64
#  4   Consolidation               36769 non-null  float64
#  5   Edema                       36769 non-null  float64
#  6   Emphysema                   36769 non-null  float64
#  7   Enlarged Cardiomediastinum  36769 non-null  float64
#  8   Fibrosis                    36769 non-null  float64
#  9   Fracture                    36769 non-null  float64
#  10  Hernia                      36769 non-null  float64
#  11  Infiltration                36769 non-null  float64
# ...
